# %%
import fitz  # PyMuPDF
import camelot
from pathlib import Path
from tqdm import tqdm
from PIL import Image
import pandas as pd
import logging
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage
import base64
import os
from io import BytesIO
import re
from typing import List, Optional, Tuple

# ======================== 로깅 ========================
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# ======================== tabula 옵션 ========================
try:
    import tabula
    TABULA_AVAILABLE = True
    logger.info("tabula-py 사용 가능")
except ImportError:
    TABULA_AVAILABLE = False
    logger.warning("tabula-py 미설치. pip install tabula-py 권장")

# ======================== OpenAI 설정 ========================
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    logger.warning("OPENAI_API_KEY 환경 변수가 없음")

# langchain-openai 최신 버전은 model 또는 model_name 모두 가능
llm = ChatOpenAI(api_key=api_key, model_name="gpt-4o", request_timeout=120)

# ======================== 상수/정규식 ========================
UNIT_HINT_RE = re.compile(r'단위\s*[:：]\s*([^\n\)\]]+)', re.IGNORECASE)
MD_TABLE_SEP_RE = re.compile(r'^\s*\|?\s*:?-{2,}:?\s*(\|\s*:?-{2,}:?\s*)+\|?\s*$', re.MULTILINE)
SERIES_GARBAGE_RE = re.compile(r'^Name:\s*\d+,\s*dtype:\s*object\.?$', re.IGNORECASE)

SKIP_TOKENS = {'', '-', 'na', 'nan', '<na>', '<NA>', 'n/a', '—'}
TOTAL_ROW_TOKENS = {'합계', '총계', '계', '소계', '누계'}
UNIT_TOKENS = ['원', '천원', '백만원', '억원', 'krw', 'usd', '%']

HEADING_RE = re.compile(r'^\s{0,3}#{1,6}\s+')
CAPTION_RE = re.compile(r'^\s*(표|그림|도표)\s*제목\s*[:：]', re.IGNORECASE)
PAGE_RE = re.compile(r'^\s*(페이지|page)\s*\d+', re.IGNORECASE)
BULLET_EMPTY_RE = re.compile(r'^\s*[-*]\s*$')

def _norm_ws(s: str) -> str:
    return re.sub(r'\s+', ' ', (s or '')).strip()

# ======================== 단위 탐지 ========================
def detect_unit_hint(text: str, headers: Optional[List[str]] = None, default_unit: Optional[str] = None) -> Optional[str]:
    m = UNIT_HINT_RE.search(text or "")
    if m:
        return m.group(1).strip()

    candidate_zone = (text or "")
    if headers:
        candidate_zone += "\n" + "\n".join([str(h) for h in headers])
    for tok in UNIT_TOKENS:
        if re.search(re.escape(tok), candidate_zone, flags=re.IGNORECASE):
            return tok

    if default_unit:
        return default_unit.strip()
    return None

# ======================== 표 감지 휴리스틱 ========================
def is_likely_table(page: fitz.Page, text: str) -> bool:
    lines = text.strip().split('\n')
    if len(lines) > 3:
        space_separated = sum(1 for line in lines if len(re.findall(r'\s{2,}', line)) >= 2)
        if space_separated / len(lines) > 0.4:
            return True
    paths = page.get_drawings()
    h_lines, v_lines = 0, 0
    for path in paths:
        for item in path['items']:
            if item[0] == 'l':
                p1, p2 = item[1], item[2]
                if abs(p1.y - p2.y) < 2: h_lines += 1
                elif abs(p1.x - p2.x) < 2: v_lines += 1
    return h_lines > 5 and v_lines > 2

# ======================== 표 추출 도구 ========================
def extract_tables_with_multiple_tools(pdf_path: Path, page_num: int) -> List[Tuple[pd.DataFrame, str, Tuple]]:
    out = []
    try:
        tables = camelot.read_pdf(str(pdf_path), pages=str(page_num + 1), flavor='lattice')
        if tables.n > 0:
            logger.info(f"p{page_num+1}: Camelot Lattice {tables.n}개")
            for t in tables:
                out.append((t.df, "Camelot-Lattice", t._bbox))
            return out
    except Exception as e:
        logger.debug(f"Camelot Lattice 오류: {e}")

    if TABULA_AVAILABLE:
        try:
            dfs = tabula.read_pdf(str(pdf_path), pages=page_num + 1, lattice=True, multiple_tables=True)
            if dfs:
                logger.info(f"p{page_num+1}: Tabula Lattice {len(dfs)}개")
                for df in dfs:
                    out.append((df, "Tabula-Lattice", (0, 0, 1, 1)))
                return out
        except Exception as e:
            logger.debug(f"Tabula Lattice 오류: {e}")

    try:
        tables = camelot.read_pdf(str(pdf_path), pages=str(page_num + 1), flavor='stream', edge_tol=500)
        if tables.n > 0:
            logger.info(f"p{page_num+1}: Camelot Stream {tables.n}개")
            for t in tables:
                out.append((t.df, "Camelot-Stream", t._bbox))
            return out
    except Exception as e:
        logger.debug(f"Camelot Stream 오류: {e}")

    return []

# ======================== DF 정리 및 단문화 ========================
def _basic_clean_df(df: pd.DataFrame) -> Optional[pd.DataFrame]:
    if df is None or df.empty:
        return None
    df = df.copy()

    # 셀 내부 개행/탭 정규화. DataFrame.apply + Series.map 사용으로 경고 회피
    def _cell_norm(x):
        return _norm_ws(str(x)) if pd.notna(x) else x
    df = df.apply(lambda col: col.map(_cell_norm))

    df.replace(r'^\s*$', pd.NA, regex=True, inplace=True)
    df.dropna(how='all', axis=0, inplace=True)
    df.dropna(how='all', axis=1, inplace=True)
    df.reset_index(drop=True, inplace=True)
    if df.empty:
        return None

    # 숫자형 인덱스 컬럼이면 첫 행을 헤더로 승격
    if all(isinstance(c, int) for c in df.columns):
        header = df.iloc[0].fillna('')
        df = df.iloc[1:].copy()
        df.columns = header
        df.reset_index(drop=True, inplace=True)

    try:
        df = df.astype(str)
    except Exception:
        df = df.apply(lambda col: col.map(lambda x: '' if pd.isna(x) else str(x)))

    return df if df.shape[0] >= 1 and df.shape[1] >= 1 else None

def _should_skip_value(v: str) -> bool:
    s = (v or '').strip().lower()
    return s in SKIP_TOKENS

def _is_total_row(key: str) -> bool:
    k = (key or '').strip()
    return any(tok in k for tok in TOTAL_ROW_TOKENS)

def df_to_sentences(df: pd.DataFrame, unit_hint_text: Optional[str] = None, row_header_idx: int = 0) -> List[str]:
    df = _basic_clean_df(df)
    if df is None:
        return []
    headers = [str(h).strip() for h in df.columns]
    unit = detect_unit_hint(unit_hint_text or "", headers=headers, default_unit=None)

    out: List[str] = []
    for _, row in df.iterrows():
        row_vals = [str(row.get(h, '')).strip() for h in headers]
        if row_header_idx >= len(row_vals):
            continue
        row_key = row_vals[row_header_idx].strip()
        if not row_key or _is_total_row(row_key):
            continue
        for c_idx, h in enumerate(headers):
            if c_idx == row_header_idx:
                continue
            col = str(h).strip()
            val = row_vals[c_idx].strip()
            if _should_skip_value(val) or SERIES_GARBAGE_RE.match(val):
                continue
            unit_str = f' {unit}' if unit else ''
            out.append(f'{row_key}, {col} {val}{unit_str}.')
    return out

def md_table_to_sentences(md_block: str, unit_hint_text: Optional[str]) -> List[str]:
    lines = [ln for ln in md_block.splitlines() if ln.strip()]
    table_lines = [ln for ln in lines if ln.count('|') >= 2 and not ln.strip().startswith('```')]
    table_lines = [ln for ln in table_lines if not MD_TABLE_SEP_RE.match(ln)]
    if not table_lines:
        return []
    def split_row(line: str) -> List[str]:
        s = line.strip()
        if s.startswith('|'): s = s[1:]
        if s.endswith('|'): s = s[:-1]
        return [c.strip() for c in s.split('|')]
    rows = [split_row(ln) for ln in table_lines]
    rows = [r for r in rows if any(c.strip() for c in r)]
    if not rows:
        return []
    headers = rows[0]
    data = rows[1:] if len(rows) > 1 else []
    max_len = max(len(r) for r in rows)
    headers += [''] * (max_len - len(headers))
    data = [r + [''] * (max_len - len(r)) for r in data]

    unit = detect_unit_hint(unit_hint_text or "", headers=headers, default_unit=None)

    out: List[str] = []
    for r in data:
        row_key = r[0].strip()
        if not row_key or _is_total_row(row_key):
            continue
        for c_idx in range(1, len(headers)):
            val = r[c_idx].strip()
            if _should_skip_value(val) or SERIES_GARBAGE_RE.match(val):
                continue
            col = headers[c_idx].strip()
            unit_str = f' {unit}' if unit else ''
            out.append(f'{row_key}, {col} {val}{unit_str}.')
    return out

# ======================== 이미지 프롬프트 ========================
IMAGE_PROMPT_KO = """당신은 시각 자료를 객관적인 문장(줄글)으로 상세하게 묘사하는 AI 어시스턴트입니다. 당신의 임무는 아래 이미지의 모든 시각적 정보를 빠짐없이 사람이 설명해주듯이 서술하는 것입니다.
이 결과는 벡터 데이터베이스에 사용되므로, 당신의 주관적인 해석이나 평가는 절대 포함되어서는 안 됩니다.

당신의 작업 지침:
1. 이미지 종류 판단: 이미지가 의미 있는 정보(그래프, 차트, 사진 등)인지, 의미 없는 장식용(로고, 배경 등)인지 먼저 판단해주세요. 의미 없는 이미지라면, 다른 설명 없이 오직 "배경 이미지" 라고만 응답해주세요.
2. 자연스러운 묘사(의미 있는 이미지일 경우):
   - 그래프/차트의 경우, 다음 정보를 포함하여 줄글로 설명해주세요: 그래프의 제목과 종류, 각 축의 정보와 단위, 각 데이터 포인트, 범례(Legend) 등
   - 일반 사진/다이어그램: 보이는 그대로의 상황, 객체, 인물, 배경, 그리고 이미지 내 텍스트를 자연스러운 문장으로 설명해주세요.
3. 엄격한 제한사항: 절대 이미지의 의미를 해석하거나, 경향을 분석하거나, 결론을 도출하지 마세요.

위 지침을 엄격히 따라서 자연스러운 한국어 줄글로 결과를 생성해주세요.
"""

def analyze_page_image_caption(page_image: Image.Image, page_num: int) -> Optional[str]:
    try:
        buffer = BytesIO()
        page_image.save(buffer, format="PNG")
        img_b64 = base64.b64encode(buffer.getvalue()).decode("utf-8")
        messages = [HumanMessage(content=[
            {"type": "text", "text": IMAGE_PROMPT_KO},
            {"type": "image_url", "image_url": {"url": f"data:image/png;base64,{img_b64}"}}
        ])]
        result = llm.invoke(messages).content.strip()
        if result and "배경 이미지" not in result:
            return result
        return None
    except Exception as e:
        logger.error(f"이미지 캡션 생성 오류: {e}")
        return None

# ======================== 텍스트 추출 보조 ========================
def extract_text_outside_bboxes(page: fitz.Page, bboxes: List[Tuple]) -> str:
    full_text = ""
    blocks = page.get_text("blocks")
    for x1, y1, x2, y2, text, _, _ in blocks:
        rect = fitz.Rect(x1, y1, x2, y2)
        inside = any(fitz.Rect(bx1, by1, bx2, by2).intersects(rect) for bx1, by1, bx2, by2 in bboxes)
        if not inside:
            full_text += text + "\n"
    return full_text.strip()

def is_cover_page(text: str) -> bool:
    return len(text) < 300 and any(k in text.lower() for k in ['보고서', 'report', '제출'])

def is_toc_page(text: str) -> bool:
    return '목차' in text or 'contents' in text.lower() or len(re.findall(r'\.{5,}\s*\d+', text)) > 3

def correct_text_with_llm(text_to_correct: str) -> str:
    if not text_to_correct.strip():
        return ""
    prompt = (
        "다음은 PDF에서 추출된 텍스트입니다. OCR 및 줄바꿈 오류를 수정하되, 의미와 내용은 변경하지 마세요.\n\n"
        "[원문]\n" + text_to_correct + "\n\n[교정]"
    )
    try:
        return llm.invoke([HumanMessage(content=prompt)]).content.strip()
    except Exception as e:
        logger.error(f"텍스트 교정 실패: {e}")
        return text_to_correct

# ======================== 벡터용 선형화 ========================
def _keep_text_line_for_vector(line: str) -> bool:
    if not line.strip(): return False
    if HEADING_RE.match(line): return False
    if CAPTION_RE.match(line): return False
    if PAGE_RE.match(line): return False
    if BULLET_EMPTY_RE.match(line): return False
    if line.startswith('---'): return False
    if line.startswith('### 이미지 설명'): return False
    return True

def stitch_markdown_flow_for_vector(md_text: str) -> List[str]:
    lines = md_text.splitlines()
    out_txt: List[str] = []
    i = 0
    while i < len(lines):
        line = lines[i]
        # 마크다운 표가 남아 있다면 단문으로 변환
        if line.count('|') >= 2 and not line.strip().startswith('```'):
            j = i + 1
            block = [line]
            while j < len(lines) and lines[j].count('|') >= 2 and not lines[j].strip().startswith('```'):
                block.append(lines[j]); j += 1
            sents = md_table_to_sentences("\n".join(block), unit_hint_text=None)
            out_txt.extend(sents)
            i = j
            continue

        if _keep_text_line_for_vector(line):
            text = _norm_ws(line)
            if text:
                out_txt.append(text)
        i += 1
    return out_txt

# ======================== PDF → MD (md를 인덱싱용으로 저장) ========================
def process_pdf_to_markdown(pdf_path: Path, output_dir: Path, default_unit: Optional[str] = None):
    logger.info(f"{pdf_path.name} 처리 시작")
    doc = fitz.open(pdf_path)
    all_md_chunks = [f"# {pdf_path.stem}"]

    for page_num in tqdm(range(len(doc)), desc=f"{pdf_path.stem} 페이지"):
        page = doc.load_page(page_num)
        page_text_full = page.get_text("text").strip()
        if is_cover_page(page_text_full) or is_toc_page(page_text_full):
            continue

        pix = page.get_pixmap(dpi=150)
        page_image = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)

        table_data = extract_tables_with_multiple_tools(pdf_path, page_num)
        table_chunks = []
        table_bboxes = []
        unit_hint_page = detect_unit_hint(page_text_full, default_unit=default_unit)

        if table_data:
            for i, (df, method, bbox) in enumerate(table_data):
                sentences = df_to_sentences(df, unit_hint_text=unit_hint_page, row_header_idx=0)
                if sentences:
                    table_chunks.append("\n".join(sentences))
                    page_h = page.rect.height
                    fitz_bbox = (bbox[0], page_h - bbox[3], bbox[2], page_h - bbox[1])
                    table_bboxes.append(fitz_bbox)

        if not table_chunks and is_likely_table(page, page_text_full):
            # 필요 시 AI 기반 표→md→단문 변환 경로 추가 가능
            pass

        # 본문 텍스트
        text_chunks = []
        remaining_text = extract_text_outside_bboxes(page, table_bboxes) if table_bboxes else page_text_full
        if remaining_text:
            corrected_text = correct_text_with_llm(remaining_text)
            text_chunks.append(f"### 텍스트 내용 (페이지 {page_num + 1})\n\n{corrected_text}")

        # 이미지 캡션은 원본 md에만 의미. 인덱싱 md에서는 제거될 것이라 선택적으로 유지
        image_chunks = []
        caption = analyze_page_image_caption(page_image, page_num)
        if caption:
            image_chunks.append(f"---\n### 이미지 설명 (페이지 {page_num + 1})\n\n{caption}")

        page_content = []
        if table_chunks:
            page_content.extend(table_chunks)
        if text_chunks:
            page_content.extend(text_chunks)
        if image_chunks:
            page_content.extend(image_chunks)

        if page_content:
            all_md_chunks.append(f"\n---\n## 페이지 {page_num + 1}\n---")
            all_md_chunks.extend(page_content)

    # 최종 저장: md를 인덱싱 규칙으로 선형화해서 저장
    safe_name = "".join(c for c in pdf_path.stem if c.isalnum() or c in (' ', '_')).rstrip()
    md_path = output_dir / f"{safe_name}.md"
    md_path.parent.mkdir(parents=True, exist_ok=True)

    md_raw = "\n\n".join(all_md_chunks)
    vector_lines = stitch_markdown_flow_for_vector(md_raw)
    md_path.write_text("\n".join(vector_lines), encoding="utf-8")

    logger.info(f"완료: {md_path}")
    return md_path

# ======================== 메인 루틴 ========================
def main():
    pdf_root = Path(r"C:\skn13\final\DB2\내부문서\test")
    output_dir = pdf_root / "_markdown_output_v9_index_md"
    output_dir.mkdir(parents=True, exist_ok=True)

    pdf_files = [p for p in pdf_root.rglob("*.pdf") if not any(part.startswith("_markdown") for part in p.parts)]
    if not pdf_files:
        logger.warning(f"PDF 없음: {pdf_root}")
        return

    logger.info(f"총 {len(pdf_files)}개 파일 처리")
    ok, fail = 0, 0
    for pdf_file in tqdm(pdf_files, desc="전체 처리"):
        try:
            _ = process_pdf_to_markdown(pdf_file, output_dir, default_unit=None)
            logger.info(f"md only: {pdf_file.stem}.md")
            ok += 1
        except Exception as e:
            logger.error(f"{pdf_file.name} 처리 실패: {e}", exc_info=True)
            fail += 1

    logger.info(f"완료. 성공 {ok}, 실패 {fail}. 결과: {output_dir.resolve()}")

if __name__ == "__main__":
    main()
# Out:
# 2025-08-14 14:27:37,981 - INFO - tabula-py 사용 가능
# 2025-08-14 14:27:37,997 - INFO - 총 9개 파일 처리
# 전체 처리:   0%|          | 0/9 [00:00<?, ?it/s]2025-08-14 14:27:37,999 - INFO - (공시) 2024년 특정감사 결과보고.pdf 처리 시작
# 2025-08-14 14:27:38,424 - INFO - p2: Tabula Lattice 1개
# 2025-08-14 14:27:41,808 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:27:55,974 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:27:56,546 - INFO - p3: Tabula Lattice 2개
# 2025-08-14 14:28:05,394 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:28:13,690 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:28:14,236 - INFO - p4: Camelot Lattice 1개
# 2025-08-14 14:28:20,472 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:28:30,995 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:28:31,468 - INFO - p5: Camelot Lattice 2개
# 2025-08-14 14:28:33,116 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:28:48,101 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:28:48,537 - INFO - p6: Camelot Lattice 2개
# 2025-08-14 14:28:49,633 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:28:50,212 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 503 Service Unavailable"
# 2025-08-14 14:28:50,214 - INFO - Retrying request to /chat/completions in 0.486038 seconds
# 2025-08-14 14:29:13,494 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:29:14,004 - INFO - p7: Camelot Lattice 1개
# 2025-08-14 14:29:21,391 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:29:41,963 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:29:42,414 - INFO - p8: Camelot Lattice 1개
# 2025-08-14 14:29:45,424 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:29:58,958 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:29:59,464 - INFO - p9: Tabula Lattice 2개
# 2025-08-14 14:30:03,473 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:30:19,352 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:30:19,841 - INFO - p10: Camelot Lattice 1개
# 2025-08-14 14:30:26,199 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:30:41,248 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:30:41,762 - INFO - p11: Tabula Lattice 1개
# 2025-08-14 14:30:46,778 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:31:03,675 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:31:04,223 - INFO - p12: Tabula Lattice 1개
# 2025-08-14 14:31:11,134 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:31:28,869 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:31:29,615 - INFO - p13: Camelot Stream 1개
# 2025-08-14 14:31:36,036 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:31:56,308 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:31:57,437 - INFO - p14: Camelot Stream 1개
# 2025-08-14 14:32:02,751 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:32:15,764 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:32:16,525 - INFO - p15: Camelot Lattice 1개
# 2025-08-14 14:32:19,876 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:32:37,370 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:32:38,142 - INFO - p16: Camelot Stream 1개
# 2025-08-14 14:32:50,685 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:32:51,544 - INFO - p17: Tabula Lattice 1개
# 2025-08-14 14:32:58,161 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:33:12,190 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:33:12,730 - INFO - p18: Tabula Lattice 1개
# 2025-08-14 14:33:21,411 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:33:35,127 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:33:35,813 - INFO - p19: Tabula Lattice 1개
# 2025-08-14 14:33:40,963 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:33:55,301 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:33:55,852 - INFO - p20: Camelot Lattice 2개
# 2025-08-14 14:33:57,000 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:34:31,140 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:34:31,650 - INFO - p21: Tabula Lattice 3개
# 2025-08-14 14:34:37,401 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:34:52,030 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:34:52,775 - INFO - p23: Camelot Stream 1개
# 2025-08-14 14:35:03,157 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:35:11,484 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:35:11,944 - INFO - p24: Camelot Lattice 1개
# 2025-08-14 14:35:16,811 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:35:31,760 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:35:32,385 - INFO - p25: Camelot Stream 1개
# 2025-08-14 14:35:39,032 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:36:07,088 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:36:07,722 - INFO - p26: Camelot Stream 1개
# 2025-08-14 14:36:16,205 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:36:28,595 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:36:29,298 - INFO - p27: Camelot Stream 1개
# 2025-08-14 14:36:36,683 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:36:47,024 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:36:47,476 - INFO - p28: Camelot Stream 1개
# 2025-08-14 14:36:49,690 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:36:56,345 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:36:57,004 - INFO - p29: Camelot Stream 1개
# 2025-08-14 14:36:58,392 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:37:13,246 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:37:13,735 - INFO - p30: Camelot Lattice 1개
# 2025-08-14 14:37:17,002 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:37:27,694 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:37:28,315 - INFO - p31: Camelot Stream 1개
# 2025-08-14 14:37:29,120 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:37:46,215 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:37:46,714 - INFO - p32: Camelot Stream 1개
# 2025-08-14 14:37:51,538 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:37:52,210 - INFO - p33: Camelot Stream 1개
# 2025-08-14 14:37:57,999 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:38:10,688 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:38:11,326 - INFO - p34: Camelot Stream 1개
# 2025-08-14 14:38:16,524 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:38:26,152 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:38:26,567 - INFO - p35: Camelot Lattice 1개
# 2025-08-14 14:38:28,097 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:38:40,388 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# (공시) 2024년 특정감사 결과보고 페이지: 100%|██████████| 35/35 [11:02<00:00, 18.92s/it]
# 2025-08-14 14:38:40,403 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\공시 2024년 특정감사 결과보고.md
# 2025-08-14 14:38:40,405 - INFO - md only: (공시) 2024년 특정감사 결과보고.md
# 전체 처리:  11%|█         | 1/9 [11:02<1:28:19, 662.41s/it]2025-08-14 14:38:40,406 - INFO - (공시) 감사 결과보고서.pdf 처리 시작
# 2025-08-14 14:38:40,916 - INFO - p2: Tabula Lattice 1개
# 2025-08-14 14:38:44,991 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:38:55,149 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:38:55,698 - INFO - p3: Tabula Lattice 2개
# 2025-08-14 14:39:02,910 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:39:16,432 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:39:16,881 - INFO - p4: Tabula Lattice 2개
# 2025-08-14 14:39:22,809 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:39:38,825 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:39:39,331 - INFO - p5: Camelot Lattice 2개
# 2025-08-14 14:39:40,639 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:39:50,324 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:39:50,812 - INFO - p6: Camelot Lattice 2개
# 2025-08-14 14:39:52,030 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:40:10,714 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:40:11,170 - INFO - p7: Tabula Lattice 3개
# 2025-08-14 14:40:17,256 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:40:27,599 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:40:28,042 - INFO - p8: Camelot Lattice 1개
# 2025-08-14 14:40:33,547 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:40:51,663 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:40:52,099 - INFO - p9: Tabula Lattice 1개
# 2025-08-14 14:40:57,089 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:41:08,660 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:41:09,135 - INFO - p10: Tabula Lattice 2개
# 2025-08-14 14:41:15,934 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:41:32,314 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:41:32,837 - INFO - p11: Camelot Lattice 2개
# 2025-08-14 14:41:37,742 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:41:56,643 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:41:57,189 - INFO - p12: Tabula Lattice 1개
# 2025-08-14 14:42:16,246 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:42:23,948 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 62.10029949999996, 553.8492320229441, 820.5385683706895)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:42:24,552 - INFO - p13: Camelot Stream 1개
# 2025-08-14 14:42:29,981 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:42:46,761 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 143.1317434999999, 553.8492320229441, 793.4269906249999)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:42:47,356 - INFO - p14: Camelot Stream 1개
# 2025-08-14 14:42:52,297 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:43:03,159 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:43:03,728 - INFO - p15: Tabula Lattice 2개
# 2025-08-14 14:43:09,801 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:43:23,728 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:43:24,223 - INFO - p16: Tabula Lattice 1개
# 2025-08-14 14:43:28,061 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:43:43,044 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 601.6306685000001, 549.5309771089887, 843.4779169843749)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:43:43,534 - INFO - p17: Camelot Stream 1개
# 2025-08-14 14:43:45,129 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:43:53,935 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:43:54,378 - INFO - p18: Tabula Lattice 1개
# 2025-08-14 14:43:56,869 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:44:07,569 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:44:08,062 - INFO - p19: Tabula Lattice 1개
# 2025-08-14 14:44:16,976 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:44:30,099 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:44:30,492 - INFO - p20: Camelot Lattice 1개
# 2025-08-14 14:44:34,830 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:44:46,295 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:44:46,804 - INFO - p21: Camelot Lattice 2개
# 2025-08-14 14:44:51,280 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:45:10,120 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 537.6206225, 547.2523314791699, 842.8579694999999)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:45:10,573 - INFO - p22: Camelot Stream 1개
# 2025-08-14 14:45:12,182 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:45:19,645 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:45:20,180 - INFO - p23: Camelot Lattice 6개
# 2025-08-14 14:45:23,947 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:45:36,133 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:45:36,573 - INFO - p24: Camelot Lattice 1개
# 2025-08-14 14:45:39,761 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:45:51,094 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:45:51,579 - INFO - p25: Camelot Lattice 2개
# 2025-08-14 14:45:52,620 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:46:02,242 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:46:02,727 - INFO - p26: Camelot Lattice 1개
# 2025-08-14 14:46:06,909 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:46:22,826 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:46:23,243 - INFO - p27: Camelot Lattice 1개
# 2025-08-14 14:46:25,440 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:46:32,963 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 400.85009349999996, 555.2872148076132, 845.0640201346154)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:46:33,441 - INFO - p28: Camelot Stream 1개
# 2025-08-14 14:46:36,373 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:46:42,804 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 68.69309449999999, 555.2878571089888, 670.0902586304348)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:46:43,350 - INFO - p29: Camelot Stream 1개
# 2025-08-14 14:46:47,404 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:46:58,567 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:46:58,987 - INFO - p30: Camelot Lattice 1개
# 2025-08-14 14:47:02,778 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:47:24,471 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 122.63414449999999, 555.287548322816, 670.0902586304348)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:47:24,987 - INFO - p31: Camelot Stream 1개
# 2025-08-14 14:47:31,025 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:47:44,542 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 180.41100249999994, 555.1689688290558, 820.8620079999998)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:47:45,104 - INFO - p32: Camelot Stream 1개
# 2025-08-14 14:47:48,543 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:47:58,882 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 98.66034450000002, 555.2876903513873, 670.0902586304348)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:47:59,410 - INFO - p33: Camelot Stream 1개
# 2025-08-14 14:48:05,331 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:48:18,745 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 571.1839425000001, 548.0361918805075, 815.2581322499999)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:48:19,140 - INFO - p34: Camelot Stream 1개
# 2025-08-14 14:48:20,587 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:48:30,560 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 87.63239649999998, 555.2873815652146, 674.0459356304349)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:48:31,150 - INFO - p35: Camelot Stream 1개
# 2025-08-14 14:48:36,462 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:48:50,490 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 416.4330635, 555.287548322816, 844.476201)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:48:50,918 - INFO - p36: Camelot Stream 1개
# 2025-08-14 14:48:55,408 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:49:04,211 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:49:04,777 - INFO - p37: Camelot Stream 1개
# 2025-08-14 14:49:05,645 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:49:21,020 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 338.27847549999996, 555.287548322816, 844.6560045)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:49:21,488 - INFO - p38: Camelot Stream 1개
# 2025-08-14 14:49:26,435 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:49:34,726 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:49:35,290 - INFO - p39: Camelot Stream 1개
# 2025-08-14 14:49:36,131 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:49:49,574 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 90.14964549999998, 555.2878571089888, 834.7924982142856)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:49:50,069 - INFO - p40: Camelot Stream 1개
# 2025-08-14 14:49:54,695 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:50:06,983 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:50:07,421 - INFO - p41: Camelot Lattice 1개
# 2025-08-14 14:50:10,260 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:50:29,832 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:50:30,301 - INFO - p42: Camelot Lattice 1개
# 2025-08-14 14:50:33,906 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:50:52,463 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:50:52,910 - INFO - p43: Tabula Lattice 1개
# 2025-08-14 14:50:56,852 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:51:11,094 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 397.9732375, 550.6114388290557, 844.476201)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:51:11,538 - INFO - p44: Camelot Stream 1개
# 2025-08-14 14:51:14,670 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:51:21,303 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 73.2481165, 554.5680803513873, 746.5967495085)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:51:21,906 - INFO - p45: Camelot Stream 1개
# 2025-08-14 14:51:27,880 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:51:41,909 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (46.60932, 312.50664049999995, 554.0878648076132, 844.6560045)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 14:51:42,359 - INFO - p46: Camelot Stream 1개
# 2025-08-14 14:51:45,866 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:52:01,876 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:52:02,217 - INFO - p47: Camelot Lattice 1개
# 2025-08-14 14:52:03,412 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:52:12,833 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# (공시) 감사 결과보고서 페이지: 100%|██████████| 47/47 [13:32<00:00, 17.29s/it]
# 2025-08-14 14:52:12,845 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\공시 감사 결과보고서.md
# 2025-08-14 14:52:12,847 - INFO - md only: (공시) 감사 결과보고서.md
# 전체 처리:  22%|██▏       | 2/9 [24:34<1:27:34, 750.66s/it]2025-08-14 14:52:12,848 - INFO - 2023 반기 별도재무상태표.pdf 처리 시작
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:218: UserWarning: No tables found on page-1
#   if self._document_has_no_text():
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:218: UserWarning: No tables found on page-1
#   if self._document_has_no_text():
# 2025-08-14 14:52:33,193 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:218: UserWarning: No tables found on page-2
#   if self._document_has_no_text():
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:218: UserWarning: No tables found on page-2
#   if self._document_has_no_text():
# 2025-08-14 14:52:49,404 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:218: UserWarning: No tables found on page-3
#   if self._document_has_no_text():
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:218: UserWarning: No tables found on page-3
#   if self._document_has_no_text():
# 2025-08-14 14:53:03,319 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023 반기 별도재무상태표 페이지: 100%|██████████| 3/3 [00:50<00:00, 16.82s/it]
# 2025-08-14 14:53:03,335 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\2023 반기 별도재무상태표.md
# 2025-08-14 14:53:03,336 - INFO - md only: 2023 반기 별도재무상태표.md
# 전체 처리:  33%|███▎      | 3/9 [25:25<43:05, 430.95s/it]  2025-08-14 14:53:03,337 - INFO - 23년도 지적사항 조치실적 및 결과_4분기 경영공시.pdf 처리 시작
# 2025-08-14 14:53:04,382 - INFO - p1: Tabula Lattice 1개
# 2025-08-14 14:53:19,602 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 502 Bad Gateway"
# 2025-08-14 14:53:19,606 - INFO - Retrying request to /chat/completions in 0.475499 seconds
# 2025-08-14 14:53:46,427 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:54:12,831 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:54:14,118 - INFO - p2: Tabula Lattice 2개
# 2025-08-14 14:54:30,974 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:55:11,393 - INFO - Retrying request to /chat/completions in 0.420115 seconds
# 2025-08-14 14:55:22,813 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:55:23,966 - INFO - p3: Tabula Lattice 2개
# 2025-08-14 14:55:41,020 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:56:15,119 - INFO - Retrying request to /chat/completions in 0.377153 seconds
# 2025-08-14 14:56:36,824 - INFO - Retrying request to /chat/completions in 0.853061 seconds
# 2025-08-14 14:57:08,738 - ERROR - 이미지 캡션 생성 오류: Connection error.
# 2025-08-14 14:57:09,868 - INFO - p4: Tabula Lattice 2개
# 2025-08-14 14:57:32,397 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 502 Bad Gateway"
# 2025-08-14 14:57:32,400 - INFO - Retrying request to /chat/completions in 0.459926 seconds
# 2025-08-14 14:58:00,879 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 14:58:21,379 - INFO - Retrying request to /chat/completions in 0.452606 seconds
# 2025-08-14 14:59:19,848 - INFO - Retrying request to /chat/completions in 0.823902 seconds
# 2025-08-14 15:00:09,795 - ERROR - 이미지 캡션 생성 오류: Connection error.
# 2025-08-14 15:00:10,813 - INFO - p5: Tabula Lattice 2개
# 2025-08-14 15:00:22,215 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:00:42,596 - INFO - Retrying request to /chat/completions in 0.433734 seconds
# 2025-08-14 15:01:00,526 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:01:01,559 - INFO - p6: Tabula Lattice 1개
# 2025-08-14 15:01:12,385 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:01:17,709 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:17,712 - INFO - Retrying request to /chat/completions in 0.462732 seconds
# 2025-08-14 15:01:33,697 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:01:34,589 - INFO - p7: Tabula Lattice 1개
# 2025-08-14 15:01:39,845 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:39,848 - INFO - Retrying request to /chat/completions in 0.375282 seconds
# 2025-08-14 15:01:45,460 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:45,463 - INFO - Retrying request to /chat/completions in 0.797085 seconds
# 2025-08-14 15:01:51,502 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:51,513 - ERROR - 텍스트 교정 실패: Error code: 500
# 2025-08-14 15:01:55,905 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:55,907 - INFO - Retrying request to /chat/completions in 0.378785 seconds
# 2025-08-14 15:01:56,331 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:56,332 - INFO - Retrying request to /chat/completions in 0.937295 seconds
# 2025-08-14 15:01:57,443 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:57,450 - ERROR - 이미지 캡션 생성 오류: Error code: 500
# 2025-08-14 15:01:58,138 - INFO - p8: Tabula Lattice 1개
# 2025-08-14 15:01:58,202 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:58,203 - INFO - Retrying request to /chat/completions in 0.470712 seconds
# 2025-08-14 15:01:58,721 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:58,722 - INFO - Retrying request to /chat/completions in 0.821406 seconds
# 2025-08-14 15:01:59,596 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:59,599 - ERROR - 텍스트 교정 실패: Error code: 500
# 2025-08-14 15:01:59,654 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:01:59,655 - INFO - Retrying request to /chat/completions in 0.478914 seconds
# 2025-08-14 15:02:00,180 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:02:00,182 - INFO - Retrying request to /chat/completions in 0.915035 seconds
# 2025-08-14 15:02:01,132 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:02:01,135 - ERROR - 이미지 캡션 생성 오류: Error code: 500
# 23년도 지적사항 조치실적 및 결과_4분기 경영공시 페이지: 100%|██████████| 8/8 [08:57<00:00, 67.22s/it]
# 2025-08-14 15:02:01,140 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\23년도 지적사항 조치실적 및 결과_4분기 경영공시.md
# 2025-08-14 15:02:01,142 - INFO - md only: 23년도 지적사항 조치실적 및 결과_4분기 경영공시.md
# 전체 처리:  44%|████▍     | 4/9 [34:23<39:25, 473.13s/it]2025-08-14 15:02:01,143 - INFO - [긴급]구매규격 사전공개 제안요청서_2025년 1인광고콘텐츠 창작자 양성 교육시설 위탁운영.pdf 처리 시작
# 2025-08-14 15:02:01,628 - INFO - p1: Camelot Lattice 1개
# 2025-08-14 15:02:05,353 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:02:24,065 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:02:24,678 - INFO - p2: Camelot Lattice 2개
# 2025-08-14 15:02:33,801 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:02:36,198 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:02:36,908 - INFO - p3: Camelot Lattice 3개
# 2025-08-14 15:02:38,657 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:02:41,351 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:02:42,548 - INFO - p4: Camelot Lattice 3개
# 2025-08-14 15:02:44,263 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:02:46,290 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:02:47,596 - INFO - p5: Camelot Lattice 3개
# 2025-08-14 15:02:51,251 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:03:01,122 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:03:02,253 - INFO - p6: Tabula Lattice 1개
# 2025-08-14 15:03:09,733 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:03:21,309 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:03:22,535 - INFO - p7: Camelot Stream 1개
# 2025-08-14 15:03:23,593 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:03:26,484 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:03:27,310 - INFO - p8: Camelot Lattice 1개
# 2025-08-14 15:03:39,945 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:03:54,488 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:03:55,892 - INFO - p9: Camelot Lattice 3개
# 2025-08-14 15:04:01,554 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:04:19,286 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:04:20,160 - INFO - p10: Camelot Lattice 2개
# 2025-08-14 15:04:30,439 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:04:41,386 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:04:41,979 - INFO - p11: Tabula Lattice 1개
# 2025-08-14 15:04:56,832 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:05:21,216 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 502 Bad Gateway"
# 2025-08-14 15:05:21,216 - INFO - Retrying request to /chat/completions in 0.422605 seconds
# 2025-08-14 15:06:00,324 - INFO - Retrying request to /chat/completions in 0.938872 seconds
# 2025-08-14 15:07:12,164 - ERROR - 이미지 캡션 생성 오류: Connection error.
# 2025-08-14 15:07:13,194 - INFO - p13: Camelot Stream 1개
# 2025-08-14 15:07:18,458 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:07:18,474 - INFO - Retrying request to /chat/completions in 0.464846 seconds
# 2025-08-14 15:07:24,204 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:07:24,204 - INFO - Retrying request to /chat/completions in 0.766373 seconds
# 2025-08-14 15:07:30,246 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:07:30,252 - ERROR - 텍스트 교정 실패: Error code: 500
# 2025-08-14 15:07:35,764 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:07:35,780 - INFO - Retrying request to /chat/completions in 0.393744 seconds
# 2025-08-14 15:07:41,511 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:07:41,511 - INFO - Retrying request to /chat/completions in 0.829334 seconds
# 2025-08-14 15:07:47,638 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:07:47,655 - ERROR - 이미지 캡션 생성 오류: Error code: 500
# 2025-08-14 15:07:48,374 - INFO - p14: Camelot Lattice 5개
# 2025-08-14 15:07:53,576 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:07:53,577 - INFO - Retrying request to /chat/completions in 0.437110 seconds
# 2025-08-14 15:08:12,741 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:08:12,744 - INFO - Retrying request to /chat/completions in 0.952777 seconds
# 2025-08-14 15:08:32,096 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:08:32,100 - ERROR - 텍스트 교정 실패: Error code: 500
# 2025-08-14 15:08:51,552 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:08:51,554 - INFO - Retrying request to /chat/completions in 0.441100 seconds
# 2025-08-14 15:09:11,520 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:09:11,523 - INFO - Retrying request to /chat/completions in 0.867374 seconds
# 2025-08-14 15:09:32,000 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:09:32,002 - ERROR - 이미지 캡션 생성 오류: Error code: 500
# 2025-08-14 15:09:32,472 - INFO - p15: Camelot Lattice 3개
# 2025-08-14 15:09:51,969 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:09:51,971 - INFO - Retrying request to /chat/completions in 0.411928 seconds
# 2025-08-14 15:10:11,939 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:10:11,941 - INFO - Retrying request to /chat/completions in 0.990211 seconds
# 2025-08-14 15:10:12,960 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:10:12,966 - ERROR - 텍스트 교정 실패: Error code: 500
# 2025-08-14 15:10:13,064 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:10:13,068 - INFO - Retrying request to /chat/completions in 0.375817 seconds
# 2025-08-14 15:10:13,575 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# 2025-08-14 15:10:13,578 - INFO - Retrying request to /chat/completions in 0.939818 seconds
# 2025-08-14 15:10:33,849 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:10:34,255 - INFO - p16: Camelot Lattice 2개
# 2025-08-14 15:10:36,175 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:10:47,574 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:10:48,152 - INFO - p17: Camelot Lattice 1개
# 2025-08-14 15:11:04,395 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:11:08,137 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:11:08,791 - INFO - p18: Camelot Lattice 3개
# 2025-08-14 15:11:16,243 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:11:19,193 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:11:19,896 - INFO - p19: Camelot Stream 1개
# 2025-08-14 15:11:23,822 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:11:28,227 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [긴급]구매규격 사전공개 제안요청서_2025년 1인광고콘텐츠 창작자 양성 교육시설 위탁운영 페이지: 100%|██████████| 19/19 [09:27<00:00, 29.85s/it]
# 2025-08-14 15:11:28,241 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\긴급구매규격 사전공개 제안요청서_2025년 1인광고콘텐츠 창작자 양성 교육시설 위탁운영.md
# 2025-08-14 15:11:28,243 - INFO - md only: [긴급]구매규격 사전공개 제안요청서_2025년 1인광고콘텐츠 창작자 양성 교육시설 위탁운영.md
# 전체 처리:  56%|█████▌    | 5/9 [43:50<33:48, 507.02s/it]2025-08-14 15:11:28,244 - INFO - [긴급]입찰공고문_2025년 해외 OTT 시장조사 및 이용행태조사 (1).pdf 처리 시작
# 2025-08-14 15:11:29,128 - INFO - p1: Tabula Lattice 1개
# 2025-08-14 15:11:35,099 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:11:54,866 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (32.48, 74.25264000000004, 569.200528, 833.1596444444442)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:11:56,384 - INFO - p2: Camelot Stream 1개
# 2025-08-14 15:12:01,198 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:12:14,734 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:12:15,307 - INFO - p3: Camelot Lattice 2개
# 2025-08-14 15:12:15,842 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:12:30,485 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (31.519999999999996, 72.7968, 566.609152, 835.803436923077)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:12:31,012 - INFO - p4: Camelot Stream 1개
# 2025-08-14 15:12:36,832 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:12:56,190 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (32.48, 83.71680000000008, 566.607664, 829.9488)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:12:56,722 - INFO - p5: Camelot Stream 1개
# 2025-08-14 15:13:07,759 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:13:21,277 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (32.48, 111.7968, 566.607712, 830.0768)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:13:21,801 - INFO - p6: Camelot Stream 1개
# 2025-08-14 15:13:28,343 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:13:41,145 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:13:41,773 - INFO - p7: Camelot Stream 1개
# 2025-08-14 15:13:48,930 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (32.48, 163.63680000000002, 566.608192, 521.8737032258066)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (31.519999999999996, 91.27680000000002, 566.609152, 834.9537032258065)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:13:49,538 - INFO - p8: Camelot Stream 2개
# 2025-08-14 15:13:56,819 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:14:19,441 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:14:19,987 - INFO - p9: Camelot Stream 1개
# 2025-08-14 15:14:20,772 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:14:34,597 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [긴급]입찰공고문_2025년 해외 OTT 시장조사 및 이용행태조사 (1) 페이지: 100%|██████████| 9/9 [03:06<00:00, 20.71s/it]
# 2025-08-14 15:14:34,607 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\긴급입찰공고문_2025년 해외 OTT 시장조사 및 이용행태조사 1.md
# 2025-08-14 15:14:34,608 - INFO - md only: [긴급]입찰공고문_2025년 해외 OTT 시장조사 및 이용행태조사 (1).md
# 전체 처리:  67%|██████▋   | 6/9 [46:56<19:53, 398.00s/it]2025-08-14 15:14:34,610 - INFO - [긴급]입찰공고문_2025년 해외 OTT 시장조사 및 이용행태조사.pdf 처리 시작
# 2025-08-14 15:14:35,493 - INFO - p1: Tabula Lattice 1개
# 2025-08-14 15:14:41,149 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:14:55,894 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (32.48, 74.25264000000004, 569.200528, 833.1596444444442)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:14:57,346 - INFO - p2: Camelot Stream 1개
# 2025-08-14 15:15:00,707 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:15:20,934 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:15:21,512 - INFO - p3: Camelot Lattice 2개
# 2025-08-14 15:15:22,695 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:15:36,241 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (31.519999999999996, 72.7968, 566.609152, 835.803436923077)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:15:37,186 - INFO - p4: Camelot Stream 1개
# 2025-08-14 15:15:43,203 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:16:03,171 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (32.48, 83.71680000000008, 566.607664, 829.9488)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:16:03,697 - INFO - p5: Camelot Stream 1개
# 2025-08-14 15:16:11,874 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:16:30,718 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (32.48, 65.23680000000006, 566.607712, 830.0768)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:16:31,622 - INFO - p6: Camelot Stream 1개
# 2025-08-14 15:16:38,285 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:16:59,692 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:17:00,802 - INFO - p7: Camelot Stream 1개
# 2025-08-14 15:17:03,488 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (32.48, 137.83680000000007, 566.608192, 496.0737032258065)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (31.519999999999996, 65.47680000000007, 566.609152, 829.9137032258066)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:17:04,436 - INFO - p8: Camelot Stream 2개
# 2025-08-14 15:17:16,901 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:17:22,124 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:17:23,087 - INFO - p9: Camelot Stream 1개
# 2025-08-14 15:17:23,758 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:17:35,130 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [긴급]입찰공고문_2025년 해외 OTT 시장조사 및 이용행태조사 페이지: 100%|██████████| 9/9 [03:00<00:00, 20.06s/it]
# 2025-08-14 15:17:35,144 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\긴급입찰공고문_2025년 해외 OTT 시장조사 및 이용행태조사.md
# 2025-08-14 15:17:35,146 - INFO - md only: [긴급]입찰공고문_2025년 해외 OTT 시장조사 및 이용행태조사.md
# 전체 처리:  78%|███████▊  | 7/9 [49:57<10:53, 326.90s/it]2025-08-14 15:17:35,148 - INFO - 코바코파트너스 회계 감사보고서 2024.pdf 처리 시작
# 2025-08-14 15:17:37,032 - INFO - p3: Tabula Lattice 1개
# 2025-08-14 15:17:41,361 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:17:53,355 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# c:\Users\Playdata\miniconda3\envs\lang_env\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (62.059999999999974, 121.82413539999988, 514.2384284, 825.8976164142856)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 2025-08-14 15:17:54,186 - INFO - p4: Camelot Stream 1개
# 2025-08-14 15:18:02,368 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:18:12,096 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:18:12,824 - INFO - p5: Tabula Lattice 2개
# 2025-08-14 15:18:16,396 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:18:25,818 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:18:26,482 - INFO - p6: Tabula Lattice 5개
# 2025-08-14 15:18:29,298 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:18:36,979 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:18:37,825 - INFO - p7: Camelot Lattice 1개
# 2025-08-14 15:18:39,743 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:19:04,941 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:19:05,607 - INFO - p8: Camelot Lattice 1개
# 2025-08-14 15:19:06,458 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:19:18,233 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:19:19,016 - INFO - p9: Camelot Lattice 1개
# 2025-08-14 15:19:20,627 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:20:58,512 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:20:58,866 - INFO - p10: Camelot Lattice 1개
# 2025-08-14 15:21:00,243 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:21:09,251 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:21:09,594 - INFO - p11: Camelot Lattice 1개
# 2025-08-14 15:21:12,490 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:21:30,650 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:21:31,115 - INFO - p12: Camelot Lattice 1개
# 2025-08-14 15:21:32,783 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:21:57,899 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:21:58,300 - INFO - p13: Tabula Lattice 1개
# 2025-08-14 15:22:03,361 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:22:21,032 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:22:21,468 - INFO - p14: Tabula Lattice 2개
# 2025-08-14 15:22:25,668 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:22:50,216 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:22:50,640 - INFO - p15: Tabula Lattice 4개
# 2025-08-14 15:22:53,597 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:23:08,665 - INFO - Retrying request to /chat/completions in 0.464609 seconds
# 2025-08-14 15:23:35,069 - INFO - Retrying request to /chat/completions in 0.781438 seconds
# 2025-08-14 15:24:00,772 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:24:01,162 - INFO - p16: Tabula Lattice 5개
# 2025-08-14 15:24:06,918 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:24:24,426 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 502 Bad Gateway"
# 2025-08-14 15:24:24,428 - INFO - Retrying request to /chat/completions in 0.487733 seconds
# 2025-08-14 15:24:57,338 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 502 Bad Gateway"
# 2025-08-14 15:24:57,341 - INFO - Retrying request to /chat/completions in 0.949490 seconds
# 2025-08-14 15:25:13,066 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:25:13,482 - INFO - p17: Camelot Lattice 1개
# 2025-08-14 15:25:20,139 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:25:45,937 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:25:46,299 - INFO - p18: Camelot Lattice 1개
# 2025-08-14 15:25:48,564 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:26:00,376 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 코바코파트너스 회계 감사보고서 2024 페이지: 100%|██████████| 18/18 [08:25<00:00, 28.07s/it]
# 2025-08-14 15:26:00,391 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\코바코파트너스 회계 감사보고서 2024.md
# 2025-08-14 15:26:00,393 - INFO - md only: 코바코파트너스 회계 감사보고서 2024.md
# 전체 처리:  89%|████████▉ | 8/9 [58:22<06:23, 383.68s/it]2025-08-14 15:26:00,394 - INFO - 한국방송광고진흥공사_경영실적+평가+조치계획+및+시정조치+결과.pdf 처리 시작
# 2025-08-14 15:26:01,147 - INFO - p1: Camelot Lattice 1개
# 2025-08-14 15:26:02,716 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:26:14,200 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:26:14,968 - INFO - p2: Camelot Lattice 2개
# 2025-08-14 15:26:16,334 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:26:20,083 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:26:20,772 - INFO - p3: Camelot Lattice 2개
# 2025-08-14 15:26:27,411 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-14 15:26:30,790 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 한국방송광고진흥공사_경영실적+평가+조치계획+및+시정조치+결과 페이지: 100%|██████████| 3/3 [00:30<00:00, 10.13s/it]
# 2025-08-14 15:26:30,800 - INFO - 완료: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md\한국방송광고진흥공사_경영실적평가조치계획및시정조치결과.md
# 2025-08-14 15:26:30,802 - INFO - md only: 한국방송광고진흥공사_경영실적+평가+조치계획+및+시정조치+결과.md
# 전체 처리: 100%|██████████| 9/9 [58:52<00:00, 392.53s/it]
# 2025-08-14 15:26:30,804 - INFO - 완료. 성공 9, 실패 0. 결과: C:\skn13\final\DB2\내부문서\test\_markdown_output_v9_index_md
